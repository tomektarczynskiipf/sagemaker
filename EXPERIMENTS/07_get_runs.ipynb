# %% [markdown]
# # INSTALL LIBRARIES

# %%
# !pip install mlflow==2.13.2 sagemaker-mlflow==0.1.0
# Out:
# Requirement already satisfied: mlflow==2.13.2 in /opt/conda/lib/python3.10/site-packages (2.13.2)
# Requirement already satisfied: sagemaker-mlflow==0.1.0 in /opt/conda/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.13.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (7.0.0)
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.1.43)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (6.10.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.6)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.8.4)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.25.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (23.2)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.1.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (4.24.4)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (15.0.0)
# Requirement already satisfied: pytz<2025 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2023.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.4.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (1.4.49)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (0.4.4)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (3.1.4)
# Requirement already satisfied: gunicorn<23 in /opt/conda/lib/python3.10/site-packages (from mlflow==2.13.2) (22.0.0)
# Requirement already satisfied: boto3>=1.34 in /opt/conda/lib/python3.10/site-packages (from sagemaker-mlflow==0.1.0) (1.34.51)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.13.2) (4.11.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.51 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.34.51)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.34->sagemaker-mlflow==0.1.0) (0.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow==2.13.2) (1.26.18)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow==2.13.2) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow==2.13.2) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow==2.13.2) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.13.2) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow==2.13.2) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.13.2) (2.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.0.0->mlflow==2.13.2) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow==2.13.2) (0.46b0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow==2.13.2) (2024.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from querystring-parser<2->mlflow==2.13.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.13.2) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow==2.13.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow==2.13.2) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.13.2) (3.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow==2.13.2) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.13.2) (5.0.0)

# %% [markdown]
# # LOAD LIBRARIES

# %%
import mlflow
from mlflow.tracking import MlflowClient

# %% [markdown]
# # SETTINGS

# %%
mlflow_arn = "arn:aws:sagemaker:eu-west-1:211125740051:mlflow-tracking-server/Sample-server"
mlflow_experiment_name = "02-sample-experiment"

# %% [markdown]
# # SET MLFLOW

# %%
mlflow.set_tracking_uri(mlflow_arn)
mlflow.set_experiment(mlflow_experiment_name)

# Initialize the client
client = MlflowClient()

# %%
# Get the experiment ID by name
experiment = client.get_experiment_by_name(mlflow_experiment_name)
if experiment is None:
    raise ValueError(f"Experiment with name '{experiment_name}' not found")

experiment_id = experiment.experiment_id

# List all runs in the experiment
runs = client.search_runs(experiment_ids=[experiment_id])

# Print the run information
for run in runs:
    print(f"Run ID: {run.info.run_id}")
    print(f"Status: {run.info.status}")
    print(f"Start Time: {run.info.start_time}")
    print(f"End Time: {run.info.end_time}")
    print(f"Metrics: {run.data.metrics}")
    print(f"Params: {run.data.params}")
    print(f"Tags: {run.data.tags}")
    print("-" * 80)
# Out:
# Run ID: 5a73b9c775394275a26954d79efbcb82
# Status: FINISHED
# Start Time: 1720002197563
# End Time: 1720002203752
# Metrics: {'mse': 3219.448009982492, 'r2': 0.39234507375446803}
# Params: {'callbacks': 'None', 'enable_categorical': 'False', 'max_delta_step': 'None', 'max_leaves': 'None', 'missing': 'nan', 'n_jobs': 'None', 'verbosity': 'None', 'objective': 'reg:squarederror', 'feature_types': 'None', 'gpu_id': 'None', 'importance_type': 'None', 'learning_rate': 'None', 'max_cat_threshold': 'None', 'random_state': '42', 'base_score': 'None', 'n_estimators': '100', 'booster': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'early_stopping_rounds': 'None', 'max_depth': '2', 'min_child_weight': 'None', 'num_parallel_tree': 'None', 'predictor': 'None', 'reg_lambda': 'None', 'scale_pos_weight': 'None', 'tree_method': 'None', 'eval_metric': 'None', 'gamma': 'None', 'grow_policy': 'None', 'interaction_constraints': 'None', 'max_bin': 'None', 'monotone_constraints': 'None', 'colsample_bytree': 'None', 'max_cat_to_onehot': 'None', 'reg_alpha': 'None', 'sampling_method': 'None', 'subsample': 'None', 'validate_parameters': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'my-custom-name', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "5a73b9c775394275a26954d79efbcb82", "artifact_path": "model", "utc_time_created": "2024-07-03 10:23:20.132261", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "0ec1de119058479cbcca734532f1935e", "mlflow_version": "2.13.2", "model_size_bytes": 40704}]'}
# --------------------------------------------------------------------------------
# Run ID: 4c1e982d84d244f2af7737bbdfa0af73
# Status: FINISHED
# Start Time: 1720002188520
# End Time: 1720002197183
# Metrics: {'mse': 3335.3621421637345, 'r2': 0.37046685325734907}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'importance_type': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_depth': '3', 'min_child_weight': 'None', 'reg_lambda': 'None', 'scale_pos_weight': 'None', 'feature_types': 'None', 'missing': 'nan', 'tree_method': 'None', 'verbosity': 'None', 'gamma': 'None', 'interaction_constraints': 'None', 'max_delta_step': 'None', 'n_estimators': '100', 'sampling_method': 'None', 'gpu_id': 'None', 'grow_policy': 'None', 'max_cat_to_onehot': 'None', 'n_jobs': 'None', 'predictor': 'None', 'reg_alpha': 'None', 'max_cat_threshold': 'None', 'monotone_constraints': 'None', 'validate_parameters': 'None', 'max_leaves': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'subsample': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'model_type': 'xgboost', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'polite-jay-128', 'mlflow.log-model.history': '[{"run_id": "4c1e982d84d244f2af7737bbdfa0af73", "artifact_path": "model", "utc_time_created": "2024-07-03 10:23:11.251023", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "2bff5a565a944c6e87726860e2936f47", "mlflow_version": "2.13.2", "model_size_bytes": 62736}]'}
# --------------------------------------------------------------------------------
# Run ID: 430a829396d4461a9521eb9225b74e20
# Status: FINISHED
# Start Time: 1720001912044
# End Time: 1720001916594
# Metrics: {'mse': 4146.626272247876}
# Params: {'max_depth': '5'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1fa14946bb5644f0a53a8dcb89a83aa9', 'mlflow.runName': 'grandiose-quail-528', 'mlflow.log-model.history': '[{"run_id": "430a829396d4461a9521eb9225b74e20", "artifact_path": "model", "utc_time_created": "2024-07-03 10:18:32.317467", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "c002b6e8a1804d5b9bd79185a2d13263", "mlflow_version": "2.13.2", "model_size_bytes": 170952}]'}
# --------------------------------------------------------------------------------
# Run ID: cbcb48363a294bca96ea489d9a1154ed
# Status: FINISHED
# Start Time: 1720001908212
# End Time: 1720001911990
# Metrics: {'mse': 4100.971950257881}
# Params: {'max_depth': '4'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1fa14946bb5644f0a53a8dcb89a83aa9', 'mlflow.runName': 'agreeable-perch-780', 'mlflow.log-model.history': '[{"run_id": "cbcb48363a294bca96ea489d9a1154ed", "artifact_path": "model", "utc_time_created": "2024-07-03 10:18:28.536120", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "45b7d8e5f7464a67bb780c83032e07c6", "mlflow_version": "2.13.2", "model_size_bytes": 107232}]'}
# --------------------------------------------------------------------------------
# Run ID: 868fc26947ab4e0485d23ae757b4491a
# Status: FINISHED
# Start Time: 1720001903968
# End Time: 1720001908146
# Metrics: {'mse': 3335.3621421637345}
# Params: {'max_depth': '3'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1fa14946bb5644f0a53a8dcb89a83aa9', 'mlflow.runName': 'redolent-trout-903', 'mlflow.log-model.history': '[{"run_id": "868fc26947ab4e0485d23ae757b4491a", "artifact_path": "model", "utc_time_created": "2024-07-03 10:18:24.322341", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "a649fef8c95645d885243c2a05f8e73d", "mlflow_version": "2.13.2", "model_size_bytes": 62736}]'}
# --------------------------------------------------------------------------------
# Run ID: b66d2ab4e7074844b9659d10cebd0b4e
# Status: FINISHED
# Start Time: 1720001899108
# End Time: 1720001903524
# Metrics: {'mse': 3219.448009982492}
# Params: {'max_depth': '2'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1fa14946bb5644f0a53a8dcb89a83aa9', 'mlflow.runName': 'rogue-colt-279', 'mlflow.log-model.history': '[{"run_id": "b66d2ab4e7074844b9659d10cebd0b4e", "artifact_path": "model", "utc_time_created": "2024-07-03 10:18:19.458849", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "15ba28c74357495e929f3ecf1845b9a5", "mlflow_version": "2.13.2", "model_size_bytes": 40704}]'}
# --------------------------------------------------------------------------------
# Run ID: 30646c6b0a0b4e3bbfd88337d75f26d6
# Status: FINISHED
# Start Time: 1720001892856
# End Time: 1720001899025
# Metrics: {'mse': 2896.421688797472}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1fa14946bb5644f0a53a8dcb89a83aa9', 'mlflow.runName': 'glamorous-moose-908', 'mlflow.log-model.history': '[{"run_id": "30646c6b0a0b4e3bbfd88337d75f26d6", "artifact_path": "model", "utc_time_created": "2024-07-03 10:18:13.330843", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "baacdc05533a4d748488f9d400bf6a89", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: 1fa14946bb5644f0a53a8dcb89a83aa9
# Status: FINISHED
# Start Time: 1720001892663
# End Time: 1720001916657
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 2889d42574734047952e254ed2fc14cd
# Status: FAILED
# Start Time: 1720001778278
# End Time: 1720001778579
# Metrics: {}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '9a50e4da39934fc19599f2c7a1a5b17f', 'mlflow.runName': 'classy-snail-728'}
# --------------------------------------------------------------------------------
# Run ID: 9a50e4da39934fc19599f2c7a1a5b17f
# Status: FAILED
# Start Time: 1720001778182
# End Time: 1720001778678
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 0dee442f46ec4bcfa162f8d2079ab3c4
# Status: FAILED
# Start Time: 1720001756231
# End Time: 1720001756802
# Metrics: {}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': 'dda0c6b8c1e447919419233526912df9', 'mlflow.runName': 'capricious-fox-249'}
# --------------------------------------------------------------------------------
# Run ID: dda0c6b8c1e447919419233526912df9
# Status: FAILED
# Start Time: 1720001756137
# End Time: 1720001756889
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 036e824fe4714fec89b7992c65a03a88
# Status: FAILED
# Start Time: 1720001746756
# End Time: 1720001746939
# Metrics: {}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '353ff248e0fc4ff5a63259cdbb36b4df', 'mlflow.runName': 'monumental-calf-193'}
# --------------------------------------------------------------------------------
# Run ID: 353ff248e0fc4ff5a63259cdbb36b4df
# Status: FAILED
# Start Time: 1720001746625
# End Time: 1720001746997
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: ca43750c24c64f4c876a5fee4ad4ac3b
# Status: FINISHED
# Start Time: 1720001502547
# End Time: 1720001512354
# Metrics: {'mse_train': 2669.1405265645344}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'gpu_id': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '1', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'predictor': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-chart', 'mlflow.log-model.history': '[{"run_id": "ca43750c24c64f4c876a5fee4ad4ac3b", "artifact_path": "model", "utc_time_created": "2024-07-03 10:11:47.490131", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "8310cbc4ceb64403a308ea97cc3fc579", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: f960a59055dd462ea26befcb5773b564
# Status: FINISHED
# Start Time: 1720000995975
# End Time: 1720001004136
# Metrics: {'mse_train': 2669.1405265645344}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'gpu_id': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '1', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'predictor': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "f960a59055dd462ea26befcb5773b564", "artifact_path": "model", "utc_time_created": "2024-07-03 10:03:19.954675", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "4165e68401eb400fb14493978f5450b9", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: 188cde77053a4adbbd316d5c182c8118
# Status: FAILED
# Start Time: 1720000988836
# End Time: 1720000989096
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data'}
# --------------------------------------------------------------------------------
# Run ID: 906ca2798535467db94ad63dc954f165
# Status: FINISHED
# Start Time: 1720000876216
# End Time: 1720000880128
# Metrics: {'example_count': 353.0, 'mean_absolute_error': 37.2667343852878, 'mean_squared_error': 2119.4428028058755, 'root_mean_squared_error': 46.0374065603817, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'r2_score': 0.6512007939116476, 'max_error': 134.8611297607422, 'mean_absolute_percentage_error': 0.32862012365893906}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "906ca2798535467db94ad63dc954f165", "artifact_path": "model", "utc_time_created": "2024-07-03 10:01:16.668147", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "88f658da873645149996da75012d3c12", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: 39bd8e08ccbf4e9d9198a80c33fb0d83
# Status: FINISHED
# Start Time: 1720000364757
# End Time: 1720000369042
# Metrics: {'example_count': 353.0, 'mean_absolute_error': 37.2667343852878, 'mean_squared_error': 2119.4428028058755, 'root_mean_squared_error': 46.0374065603817, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'r2_score': 0.6512007939116476, 'max_error': 134.8611297607422, 'mean_absolute_percentage_error': 0.32862012365893906}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "39bd8e08ccbf4e9d9198a80c33fb0d83", "artifact_path": "model", "utc_time_created": "2024-07-03 09:52:45.647466", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "9e3e0676a3914380b35d50386df78502", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: a72c8b92c1504f6ea6aefbf3d01e5ab1
# Status: FINISHED
# Start Time: 1720000252832
# End Time: 1720000263438
# Metrics: {'mean_absolute_error': 37.2667343852878, 'root_mean_squared_error': 46.0374065603817, 'example_count': 353.0, 'mean_squared_error': 2119.4428028058755, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'max_error': 134.8611297607422, 'r2_score': 0.6512007939116476, 'mean_absolute_percentage_error': 0.32862012365893906}
# Params: {'base_score': 'None', 'enable_categorical': 'False', 'max_cat_threshold': 'None', 'n_estimators': '100', 'validate_parameters': 'None', 'early_stopping_rounds': 'None', 'grow_policy': 'None', 'max_leaves': 'None', 'predictor': 'None', 'verbosity': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'gpu_id': 'None', 'importance_type': 'None', 'learning_rate': 'None', 'max_delta_step': 'None', 'min_child_weight': 'None', 'monotone_constraints': 'None', 'random_state': '42', 'subsample': 'None', 'booster': 'None', 'colsample_bylevel': 'None', 'max_bin': 'None', 'reg_lambda': 'None', 'objective': 'reg:squarederror', 'feature_types': 'None', 'interaction_constraints': 'None', 'max_cat_to_onehot': 'None', 'max_depth': '1', 'missing': 'nan', 'reg_alpha': 'None', 'callbacks': 'None', 'eval_metric': 'None', 'num_parallel_tree': 'None', 'sampling_method': 'None', 'gamma': 'None', 'n_jobs': 'None', 'scale_pos_weight': 'None', 'tree_method': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "a72c8b92c1504f6ea6aefbf3d01e5ab1", "artifact_path": "model", "utc_time_created": "2024-07-03 09:50:56.704931", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "e6119f4fe96d40ca91a990aac073394e", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: aab55b4361d94955bb25002c8bbb8647
# Status: FINISHED
# Start Time: 1720000176484
# End Time: 1720000176828
# Metrics: {'example_count': 353.0, 'mean_absolute_error': 37.2667343852878, 'mean_squared_error': 2119.4428028058755, 'root_mean_squared_error': 46.0374065603817, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'r2_score': 0.6512007939116476, 'max_error': 134.8611297607422, 'mean_absolute_percentage_error': 0.32862012365893906}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'marvelous-elk-277'}
# --------------------------------------------------------------------------------
# Run ID: c09701289570483092140d8d1bfee23f
# Status: FINISHED
# Start Time: 1719999965383
# End Time: 1719999965671
# Metrics: {'example_count': 353.0, 'mean_absolute_error': 37.2667343852878, 'mean_squared_error': 2119.4428028058755, 'root_mean_squared_error': 46.0374065603817, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'r2_score': 0.6512007939116476, 'max_error': 134.8611297607422, 'mean_absolute_percentage_error': 0.32862012365893906}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nosy-whale-173'}
# --------------------------------------------------------------------------------
# Run ID: 651f69fe227f4cedb5d9e9e51e3efe5e
# Status: FINISHED
# Start Time: 1719998736953
# End Time: 1719998744769
# Metrics: {}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'gpu_id': 'None', 'importance_type': 'None', 'max_delta_step': 'None', 'grow_policy': 'None', 'max_bin': 'None', 'random_state': '42', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_depth': '1', 'missing': 'nan', 'n_estimators': '100', 'num_parallel_tree': 'None', 'max_cat_threshold': 'None', 'reg_alpha': 'None', 'sampling_method': 'None', 'subsample': 'None', 'validate_parameters': 'None', 'max_cat_to_onehot': 'None', 'monotone_constraints': 'None', 'n_jobs': 'None', 'predictor': 'None', 'max_leaves': 'None', 'reg_lambda': 'None', 'scale_pos_weight': 'None', 'tree_method': 'None', 'verbosity': 'None', 'min_child_weight': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "651f69fe227f4cedb5d9e9e51e3efe5e", "artifact_path": "model", "utc_time_created": "2024-07-03 09:25:40.162997", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "591494eb59d94d8e9ec30d947efa1eff", "mlflow_version": "2.13.2", "model_size_bytes": 27456}]'}
# --------------------------------------------------------------------------------
# Run ID: 7131064a61ee4395b52e811f413f0741
# Status: FINISHED
# Start Time: 1719997845237
# End Time: 1719997851784
# Metrics: {'mse': 3219.448009982492, 'r2': 0.39234507375446803}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'gpu_id': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '2', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'predictor': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'my-custom-name', 'mlflow.log-model.history': '[{"run_id": "7131064a61ee4395b52e811f413f0741", "artifact_path": "model", "utc_time_created": "2024-07-03 09:10:47.897863", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "99f5fbfbf1aa4b2498501acaee1f2708", "mlflow_version": "2.13.2", "model_size_bytes": 40704}]'}
# --------------------------------------------------------------------------------
# Run ID: 7a4f28b975a54348b28a9a1916c9352c
# Status: FINISHED
# Start Time: 1719997613563
# End Time: 1719997619776
# Metrics: {'mse': 3335.3621421637345, 'r2': 0.37046685325734907}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'gpu_id': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '3', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'predictor': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'upset-owl-909', 'mlflow.log-model.history': '[{"run_id": "7a4f28b975a54348b28a9a1916c9352c", "artifact_path": "model", "utc_time_created": "2024-07-03 09:06:56.201398", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.10.14", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "1.7.6", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "0d5883decca044eb932857c41771ae19", "mlflow_version": "2.13.2", "model_size_bytes": 62736}]'}
# --------------------------------------------------------------------------------

# %% [markdown]
# # GET MSE FOR ALL RUNS

# %%
runs_with_mse = [r for r in runs if "mse" in r.data.metrics.keys()]
[r.data.metrics["mse"] for r in runs_with_mse]
# Out:
# [3219.448009982492,
#  3335.3621421637345,
#  4146.626272247876,
#  4100.971950257881,
#  3335.3621421637345,
#  3219.448009982492,
#  2896.421688797472,
#  3219.448009982492,
#  3335.3621421637345]

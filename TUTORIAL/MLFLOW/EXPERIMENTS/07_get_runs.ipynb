# %% [markdown]
# # LOAD LIBRARIES

# %%
import mlflow
from mlflow.tracking import MlflowClient

# %% [markdown]
# # SETTINGS

# %%
mlflow_arn = "arn:aws:sagemaker:eu-west-1:575618486322:mlflow-tracking-server/dev-mlflow"
mlflow_experiment_name = "02-sample-experiment"

# %% [markdown]
# # SET MLFLOW

# %%
mlflow.set_tracking_uri(mlflow_arn)
mlflow.set_experiment(mlflow_experiment_name)

# Initialize the client
client = MlflowClient()

# %% [markdown]
# # GET RUNS

# %%
# Get the experiment ID by name
experiment = client.get_experiment_by_name(mlflow_experiment_name)
if experiment is None:
    raise ValueError(f"Experiment with name '{experiment_name}' not found")

experiment_id = experiment.experiment_id

# List all runs in the experiment
runs = client.search_runs(experiment_ids=[experiment_id])

# Print the run information
for run in runs:
    print(f"Run ID: {run.info.run_id}")
    print(f"Status: {run.info.status}")
    print(f"Start Time: {run.info.start_time}")
    print(f"End Time: {run.info.end_time}")
    print(f"Metrics: {run.data.metrics}")
    print(f"Params: {run.data.params}")
    print(f"Tags: {run.data.tags}")
    print("-" * 80)
# Out:
# Run ID: 57119b7eb46d4fbd9b5bafb37673bd98
# Status: FINISHED
# Start Time: 1730291520534
# End Time: 1730291527221
# Metrics: {'mse': 3488.5372852116648, 'r2': 0.34155580081518055}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '3', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'input-example', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "57119b7eb46d4fbd9b5bafb37673bd98", "artifact_path": "mymodel", "utc_time_created": "2024-10-30 12:32:03.402627", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "b9cf8b6733be459692f5bbb6d140e204", "mlflow_version": "2.15.1", "signature": {"inputs": "[{\\"type\\": \\"double\\", \\"name\\": \\"age\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"sex\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"bmi\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"bp\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s1\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s2\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s3\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s4\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s5\\", \\"required\\": true}, {\\"type\\": \\"double\\", \\"name\\": \\"s6\\", \\"required\\": true}]", "outputs": "[{\\"type\\": \\"float\\", \\"required\\": true}]", "params": null}, "saved_input_example_info": {"artifact_path": "input_example.json", "type": "dataframe", "pandas_orient": "split", "serving_input_path": "serving_input_payload.json"}, "model_size_bytes": 64611}]'}
# --------------------------------------------------------------------------------
# Run ID: 63128055647f4e40995c0227ad102eb4
# Status: FINISHED
# Start Time: 1730291451354
# End Time: 1730291462587
# Metrics: {'mse': 3488.5372852116648, 'r2': 0.34155580081518055}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '3', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'input-example', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "63128055647f4e40995c0227ad102eb4", "artifact_path": "mymodel", "utc_time_created": "2024-10-30 12:30:53.785090", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "932cfe6029684263b6fba4868247cc99", "mlflow_version": "2.15.1", "saved_input_example_info": {"artifact_path": "input_example.json", "type": "ndarray", "format": "tf-serving", "serving_input_path": "serving_input_payload.json"}, "model_size_bytes": 64304}]'}
# --------------------------------------------------------------------------------
# Run ID: 31ab4d1841884f8795360c682f3adc59
# Status: FINISHED
# Start Time: 1730291276424
# End Time: 1730291276759
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Tomek', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'customer_username'}
# --------------------------------------------------------------------------------
# Run ID: 2fcee3f47903455dadfbb58789ad2a16
# Status: FINISHED
# Start Time: 1730290099869
# End Time: 1730290100084
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Bob', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'username'}
# --------------------------------------------------------------------------------
# Run ID: 7227feb14d9746eba47d3b057ffaa380
# Status: FINISHED
# Start Time: 1730290062709
# End Time: 1730290062902
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Bob', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'brawny-vole-722'}
# --------------------------------------------------------------------------------
# Run ID: 51a66a35225841f9bfd5fe457b034aba
# Status: FINISHED
# Start Time: 1730290055408
# End Time: 1730290055673
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Bob', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'likeable-shrew-15'}
# --------------------------------------------------------------------------------
# Run ID: e0daa2871f1541afa494d199a2dfd03c
# Status: FINISHED
# Start Time: 1730290048022
# End Time: 1730290048229
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Bob', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'flawless-bass-396'}
# --------------------------------------------------------------------------------
# Run ID: 88c92bd3e830469ca7a4d217cba5c4dd
# Status: FINISHED
# Start Time: 1730289994732
# End Time: 1730289994925
# Metrics: {'example_metric': 0.95}
# Params: {'example_param': '42'}
# Tags: {'mlflow.user': 'Bob', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'adaptable-chimp-905'}
# --------------------------------------------------------------------------------
# Run ID: 70866bbc79584a709fc522af906313bf
# Status: FINISHED
# Start Time: 1730288442213
# End Time: 1730288450572
# Metrics: {'mse': 3421.0508582929183, 'r2': 0.35429353089957105}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'max_bin': 'None', 'max_cat_to_onehot': 'None', 'missing': 'nan', 'reg_lambda': 'None', 'scale_pos_weight': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'max_depth': '2', 'num_parallel_tree': 'None', 'reg_alpha': 'None', 'tree_method': 'None', 'learning_rate': 'None', 'max_cat_threshold': 'None', 'min_child_weight': 'None', 'monotone_constraints': 'None', 'sampling_method': 'None', 'max_delta_step': 'None', 'max_leaves': 'None', 'random_state': '42', 'subsample': 'None', 'multi_strategy': 'None', 'n_jobs': 'None', 'verbosity': 'None', 'n_estimators': '100', 'validate_parameters': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'manual_run_lifecycle', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "70866bbc79584a709fc522af906313bf", "artifact_path": "model", "utc_time_created": "2024-10-30 11:40:45.095525", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "1a611d6372cd4b738e893887f4d810e3", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: ae5e11fecce346719205071814cce379
# Status: FINISHED
# Start Time: 1730287390252
# End Time: 1730287404128
# Metrics: {'mse': 3421.0508582929183, 'r2': 0.35429353089957105, 'system/cpu_utilization_percentage': 100.0, 'system/system_memory_usage_megabytes': 3153.2, 'system/system_memory_usage_percentage': 78.1, 'system/disk_usage_percentage': 0.0, 'system/disk_usage_megabytes': 0.1, 'system/disk_available_megabytes': 39728.4, 'system/network_receive_megabytes': 0.003461999999998966, 'system/network_transmit_megabytes': 0.00484199999999646}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '2', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'my-custom-name-new', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "ae5e11fecce346719205071814cce379", "artifact_path": "model", "utc_time_created": "2024-10-30 11:23:12.951278", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "a3169f064b684c17979ef4fb59f15d08", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: 4a00fe53424b4d1ea34294505682bc4b
# Status: FINISHED
# Start Time: 1730286819049
# End Time: 1730286823306
# Metrics: {'mse': 3273.76964493031}
# Params: {'max_depth': '5'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1807da178f3c4c0b9060691245ec807e', 'mlflow.runName': 'my-param5', 'mlflow.log-model.history': '[{"run_id": "4a00fe53424b4d1ea34294505682bc4b", "artifact_path": "model", "utc_time_created": "2024-10-30 11:13:39.379895", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "4bca13e754f14a9cbcfc2c7164afdb98", "mlflow_version": "2.15.1", "model_size_bytes": 179716}]'}
# --------------------------------------------------------------------------------
# Run ID: 468f4198e1934d889e243508d5f06812
# Status: FINISHED
# Start Time: 1730286814720
# End Time: 1730286818919
# Metrics: {'mse': 3392.3649615354866}
# Params: {'max_depth': '4'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1807da178f3c4c0b9060691245ec807e', 'mlflow.runName': 'my-param4', 'mlflow.log-model.history': '[{"run_id": "468f4198e1934d889e243508d5f06812", "artifact_path": "model", "utc_time_created": "2024-10-30 11:13:35.091987", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "ce5607a68ac148fa9b13b1b0b8791b0f", "mlflow_version": "2.15.1", "model_size_bytes": 107860}]'}
# --------------------------------------------------------------------------------
# Run ID: 99f3603bb9af471aa6093bf8b027afd1
# Status: FINISHED
# Start Time: 1730286810766
# End Time: 1730286814593
# Metrics: {'mse': 3488.5372852116648}
# Params: {'max_depth': '3'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1807da178f3c4c0b9060691245ec807e', 'mlflow.runName': 'my-param3', 'mlflow.log-model.history': '[{"run_id": "99f3603bb9af471aa6093bf8b027afd1", "artifact_path": "model", "utc_time_created": "2024-10-30 11:13:31.034854", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "f05e0200084640d9b970ca6e100c031a", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]'}
# --------------------------------------------------------------------------------
# Run ID: bb83c242613c4ac490fe98cd7e4a6379
# Status: FINISHED
# Start Time: 1730286806733
# End Time: 1730286810619
# Metrics: {'mse': 3421.0508582929183}
# Params: {'max_depth': '2'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1807da178f3c4c0b9060691245ec807e', 'mlflow.runName': 'my-param2', 'mlflow.log-model.history': '[{"run_id": "bb83c242613c4ac490fe98cd7e4a6379", "artifact_path": "model", "utc_time_created": "2024-10-30 11:13:27.027487", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "e90a81d329e943819a2efb7223515dc3", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: b4c3885ccf654556b716015683c375f1
# Status: FINISHED
# Start Time: 1730286802551
# End Time: 1730286806567
# Metrics: {'mse': 2881.380066827086}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '1807da178f3c4c0b9060691245ec807e', 'mlflow.runName': 'my-param1', 'mlflow.log-model.history': '[{"run_id": "b4c3885ccf654556b716015683c375f1", "artifact_path": "model", "utc_time_created": "2024-10-30 11:13:22.825578", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "122a802ddf5249f2a330003ad7d5c510", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: 1807da178f3c4c0b9060691245ec807e
# Status: FINISHED
# Start Time: 1730286802453
# End Time: 1730286823455
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: a9969c28ffad420696101476feba54af
# Status: FINISHED
# Start Time: 1730286757718
# End Time: 1730286761491
# Metrics: {'mse': 3273.76964493031}
# Params: {'max_depth': '5'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '78e42bb4e8ce463f8db8d9cc3a8d13d2', 'mlflow.runName': 'my-param[1, 2, 3, 4, 5]', 'mlflow.log-model.history': '[{"run_id": "a9969c28ffad420696101476feba54af", "artifact_path": "model", "utc_time_created": "2024-10-30 11:12:38.078130", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "04e09527fbeb4da8b87c09d43126b1fe", "mlflow_version": "2.15.1", "model_size_bytes": 179716}]'}
# --------------------------------------------------------------------------------
# Run ID: 2304587d20ae4e689e33e89e9c8df7ab
# Status: FINISHED
# Start Time: 1730286752987
# End Time: 1730286757539
# Metrics: {'mse': 3392.3649615354866}
# Params: {'max_depth': '4'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '78e42bb4e8ce463f8db8d9cc3a8d13d2', 'mlflow.runName': 'my-param[1, 2, 3, 4, 5]', 'mlflow.log-model.history': '[{"run_id": "2304587d20ae4e689e33e89e9c8df7ab", "artifact_path": "model", "utc_time_created": "2024-10-30 11:12:33.324866", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "8c70734b725e4cc081aed81304984c99", "mlflow_version": "2.15.1", "model_size_bytes": 107860}]'}
# --------------------------------------------------------------------------------
# Run ID: ca14e838057c43b6a3d6eeab6c045585
# Status: FINISHED
# Start Time: 1730286749666
# End Time: 1730286752845
# Metrics: {'mse': 3488.5372852116648}
# Params: {'max_depth': '3'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '78e42bb4e8ce463f8db8d9cc3a8d13d2', 'mlflow.runName': 'my-param[1, 2, 3, 4, 5]', 'mlflow.log-model.history': '[{"run_id": "ca14e838057c43b6a3d6eeab6c045585", "artifact_path": "model", "utc_time_created": "2024-10-30 11:12:29.929876", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "d087376084f641da89ce9692a74426c4", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]'}
# --------------------------------------------------------------------------------
# Run ID: d9a2e46d49c74ccaa9534a9ac737c203
# Status: FINISHED
# Start Time: 1730286746106
# End Time: 1730286749522
# Metrics: {'mse': 3421.0508582929183}
# Params: {'max_depth': '2'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '78e42bb4e8ce463f8db8d9cc3a8d13d2', 'mlflow.runName': 'my-param[1, 2, 3, 4, 5]', 'mlflow.log-model.history': '[{"run_id": "d9a2e46d49c74ccaa9534a9ac737c203", "artifact_path": "model", "utc_time_created": "2024-10-30 11:12:26.339098", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "d64cd1a9f9ca496ba3d7c0ab480c211a", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: 4bfc871d58e343a8b5851b4d0439adcb
# Status: FINISHED
# Start Time: 1730286741813
# End Time: 1730286745966
# Metrics: {'mse': 2881.380066827086}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '78e42bb4e8ce463f8db8d9cc3a8d13d2', 'mlflow.runName': 'my-param[1, 2, 3, 4, 5]', 'mlflow.log-model.history': '[{"run_id": "4bfc871d58e343a8b5851b4d0439adcb", "artifact_path": "model", "utc_time_created": "2024-10-30 11:12:22.106876", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "cf771fe1f2ab40dca84987fc2f2ef563", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: 78e42bb4e8ce463f8db8d9cc3a8d13d2
# Status: FINISHED
# Start Time: 1730286741719
# End Time: 1730286761610
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 8c6dc42031fc4158b12677f32f115423
# Status: FINISHED
# Start Time: 1730286584469
# End Time: 1730286587974
# Metrics: {'mse': 3273.76964493031}
# Params: {'max_depth': '5'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '92df479429ea4d68b7063121d03c83e9', 'mlflow.runName': 'languid-steed-311', 'mlflow.log-model.history': '[{"run_id": "8c6dc42031fc4158b12677f32f115423", "artifact_path": "model", "utc_time_created": "2024-10-30 11:09:44.796701", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "a35943933f5d48db9f67e2b1927c5669", "mlflow_version": "2.15.1", "model_size_bytes": 179716}]'}
# --------------------------------------------------------------------------------
# Run ID: 463a0bf876a74c678af5af65b8e34ecc
# Status: FINISHED
# Start Time: 1730286581154
# End Time: 1730286584353
# Metrics: {'mse': 3392.3649615354866}
# Params: {'max_depth': '4'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '92df479429ea4d68b7063121d03c83e9', 'mlflow.runName': 'bouncy-eel-886', 'mlflow.log-model.history': '[{"run_id": "463a0bf876a74c678af5af65b8e34ecc", "artifact_path": "model", "utc_time_created": "2024-10-30 11:09:41.420991", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "4caa4cc886794fe1a627cd01082b139f", "mlflow_version": "2.15.1", "model_size_bytes": 107860}]'}
# --------------------------------------------------------------------------------
# Run ID: 900c450196684e53be787f2bb108fab9
# Status: FINISHED
# Start Time: 1730286577913
# End Time: 1730286581037
# Metrics: {'mse': 3488.5372852116648}
# Params: {'max_depth': '3'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '92df479429ea4d68b7063121d03c83e9', 'mlflow.runName': 'enthused-duck-452', 'mlflow.log-model.history': '[{"run_id": "900c450196684e53be787f2bb108fab9", "artifact_path": "model", "utc_time_created": "2024-10-30 11:09:38.140027", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "438b57676f0e439a849fe57665df55e1", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]'}
# --------------------------------------------------------------------------------
# Run ID: ed0d6e683025456fae12ecf87b957b4c
# Status: FINISHED
# Start Time: 1730286574393
# End Time: 1730286577799
# Metrics: {'mse': 3421.0508582929183}
# Params: {'max_depth': '2'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '92df479429ea4d68b7063121d03c83e9', 'mlflow.runName': 'monumental-auk-976', 'mlflow.log-model.history': '[{"run_id": "ed0d6e683025456fae12ecf87b957b4c", "artifact_path": "model", "utc_time_created": "2024-10-30 11:09:34.670211", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "c44d911d535a40ce90f69959bd131161", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: 375d834ce61b4395871cfd597be97154
# Status: FINISHED
# Start Time: 1730286568502
# End Time: 1730286574019
# Metrics: {'mse': 2881.380066827086}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '92df479429ea4d68b7063121d03c83e9', 'mlflow.runName': 'thoughtful-snipe-887', 'mlflow.log-model.history': '[{"run_id": "375d834ce61b4395871cfd597be97154", "artifact_path": "model", "utc_time_created": "2024-10-30 11:09:28.726495", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "b3c0881775be45a581fa7d3a1272fb34", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: 92df479429ea4d68b7063121d03c83e9
# Status: FINISHED
# Start Time: 1730286568395
# End Time: 1730286588112
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 7ebea217a52e4f50a9d577befc954d83
# Status: FAILED
# Start Time: 1730286538292
# End Time: 1730286538547
# Metrics: {'mse': 2881.380066827086}
# Params: {'max_depth': '1'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.parentRunId': '7b61695c56654161a15743320c9d9d39', 'mlflow.runName': 'thoughtful-rat-580'}
# --------------------------------------------------------------------------------
# Run ID: 7b61695c56654161a15743320c9d9d39
# Status: FAILED
# Start Time: 1730286538198
# End Time: 1730286538692
# Metrics: {}
# Params: {}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'nested-run'}
# --------------------------------------------------------------------------------
# Run ID: 1087d8e820dc42b8be84ee3156c3d38b
# Status: FINISHED
# Start Time: 1730286344599
# End Time: 1730286355710
# Metrics: {'mse_train': 2668.8169945921913}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'monotone_constraints': 'None', 'n_estimators': '100', 'num_parallel_tree': 'None', 'sampling_method': 'None', 'subsample': 'None', 'validate_parameters': 'None', 'max_delta_step': 'None', 'min_child_weight': 'None', 'max_depth': '1', 'reg_lambda': 'None', 'max_leaves': 'None', 'missing': 'nan', 'multi_strategy': 'None', 'n_jobs': 'None', 'reg_alpha': 'None', 'verbosity': 'None', 'random_state': '42', 'scale_pos_weight': 'None', 'tree_method': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-chart', 'mlflow.log-model.history': '[{"run_id": "1087d8e820dc42b8be84ee3156c3d38b", "artifact_path": "model", "utc_time_created": "2024-10-30 11:05:48.344318", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "028d8020e1fd4d3e9cf7a5686130e581", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: a36a2d8bec4e480f8a238a89091f4319
# Status: FINISHED
# Start Time: 1730285877153
# End Time: 1730285887725
# Metrics: {'example_count': 353.0, 'mean_absolute_error': 37.36061908840795, 'mean_squared_error': 2119.470563771735, 'root_mean_squared_error': 46.03770806384409, 'sum_on_target': 54269.0, 'mean_on_target': 153.73654390934846, 'r2_score': 0.6511962252566976, 'max_error': 134.82955932617188, 'mean_absolute_percentage_error': 0.330382498837417}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '1', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "a36a2d8bec4e480f8a238a89091f4319", "artifact_path": "model", "utc_time_created": "2024-10-30 10:58:00.364524", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "463a098bd5cd4c38913b94cabb7818f3", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: 85889e87545b4fee967f3dd45a1c8a21
# Status: FINISHED
# Start Time: 1730285750711
# End Time: 1730285759356
# Metrics: {}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '1', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'run-with-data', 'mlflow.log-model.history': '[{"run_id": "85889e87545b4fee967f3dd45a1c8a21", "artifact_path": "model", "utc_time_created": "2024-10-30 10:55:53.430487", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "c33d92e7bf9e46bebdce2e61adfac535", "mlflow_version": "2.15.1", "model_size_bytes": 26500}]'}
# --------------------------------------------------------------------------------
# Run ID: 068851125fb2432e93cac46acb81daae
# Status: FINISHED
# Start Time: 1730285519698
# End Time: 1730285527298
# Metrics: {'mse': 3421.0508582929183, 'r2': 0.35429353089957105}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_delta_step': 'None', 'reg_lambda': 'None', 'max_cat_to_onehot': 'None', 'n_estimators': '100', 'tree_method': 'None', 'max_depth': '2', 'validate_parameters': 'None', 'max_leaves': 'None', 'sampling_method': 'None', 'min_child_weight': 'None', 'monotone_constraints': 'None', 'random_state': '42', 'subsample': 'None', 'missing': 'nan', 'multi_strategy': 'None', 'reg_alpha': 'None', 'n_jobs': 'None', 'scale_pos_weight': 'None', 'num_parallel_tree': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'my-custom-name', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "068851125fb2432e93cac46acb81daae", "artifact_path": "model", "utc_time_created": "2024-10-30 10:52:03.259389", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "a491e1838bf442e4859651248210ace2", "mlflow_version": "2.15.1", "model_size_bytes": 39532}]'}
# --------------------------------------------------------------------------------
# Run ID: 8195ec1a094349afb580725eddfe47eb
# Status: FINISHED
# Start Time: 1730285415562
# End Time: 1730285421195
# Metrics: {'mse': 3488.5372852116648, 'r2': 0.34155580081518055}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '3', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'overjoyed-doe-579', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "8195ec1a094349afb580725eddfe47eb", "artifact_path": "mymodel", "utc_time_created": "2024-10-30 10:50:18.127243", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "a1dccb76b15944eb95963ffbdeebd21f", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]'}
# --------------------------------------------------------------------------------
# Run ID: 3535b63130f14701abf1498c3e0cd79f
# Status: FAILED
# Start Time: 1730285394854
# End Time: 1730285401006
# Metrics: {'mse': 3488.5372852116648, 'r2': 0.34155580081518055}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'eval_metric': 'None', 'feature_types': 'None', 'gamma': 'None', 'grow_policy': 'None', 'importance_type': 'None', 'interaction_constraints': 'None', 'learning_rate': 'None', 'max_bin': 'None', 'max_cat_threshold': 'None', 'max_cat_to_onehot': 'None', 'max_delta_step': 'None', 'max_depth': '3', 'max_leaves': 'None', 'min_child_weight': 'None', 'missing': 'nan', 'monotone_constraints': 'None', 'multi_strategy': 'None', 'n_estimators': '100', 'n_jobs': 'None', 'num_parallel_tree': 'None', 'random_state': '42', 'reg_alpha': 'None', 'reg_lambda': 'None', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'subsample': 'None', 'tree_method': 'None', 'validate_parameters': 'None', 'verbosity': 'None'}
# Tags: {'mlflow.log-model.history': '[{"run_id": "3535b63130f14701abf1498c3e0cd79f", "artifact_path": "mymodel", "utc_time_created": "2024-10-30 10:49:57.727840", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "d0a63d10a9f743bb8383b0a871eebbd3", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]', 'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'adorable-wren-710', 'model_type': 'xgboost'}
# --------------------------------------------------------------------------------
# Run ID: 4534348291924d9b9f79682cafad5e27
# Status: FINISHED
# Start Time: 1730285308643
# End Time: 1730285318087
# Metrics: {'mse': 3488.5372852116648, 'r2': 0.34155580081518055}
# Params: {'objective': 'reg:squarederror', 'base_score': 'None', 'booster': 'None', 'callbacks': 'None', 'colsample_bylevel': 'None', 'colsample_bynode': 'None', 'colsample_bytree': 'None', 'device': 'None', 'gamma': 'None', 'learning_rate': 'None', 'multi_strategy': 'None', 'validate_parameters': 'None', 'early_stopping_rounds': 'None', 'enable_categorical': 'False', 'feature_types': 'None', 'grow_policy': 'None', 'max_bin': 'None', 'max_leaves': 'None', 'missing': 'nan', 'n_estimators': '100', 'sampling_method': 'None', 'scale_pos_weight': 'None', 'eval_metric': 'None', 'max_cat_threshold': 'None', 'min_child_weight': 'None', 'monotone_constraints': 'None', 'n_jobs': 'None', 'importance_type': 'None', 'max_cat_to_onehot': 'None', 'random_state': '42', 'subsample': 'None', 'interaction_constraints': 'None', 'num_parallel_tree': 'None', 'reg_alpha': 'None', 'tree_method': 'None', 'max_delta_step': 'None', 'reg_lambda': 'None', 'max_depth': '3', 'verbosity': 'None'}
# Tags: {'mlflow.user': 'sagemaker-user', 'mlflow.source.name': '/opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.runName': 'welcoming-ram-423', 'model_type': 'xgboost', 'mlflow.log-model.history': '[{"run_id": "4534348291924d9b9f79682cafad5e27", "artifact_path": "model", "utc_time_created": "2024-10-30 10:48:31.454406", "flavors": {"python_function": {"loader_module": "mlflow.xgboost", "python_version": "3.11.9", "data": "model.xgb", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "xgboost": {"xgb_version": "2.0.3", "data": "model.xgb", "model_class": "xgboost.sklearn.XGBRegressor", "model_format": "xgb", "code": null}}, "model_uuid": "78afa07079204c199c191f639b354003", "mlflow_version": "2.15.1", "model_size_bytes": 63796}]'}
# --------------------------------------------------------------------------------

# %% [markdown]
# # SEARCH RUNS

# %%
best_run = client.search_runs(
    experiment_id, order_by=["metrics.r2"], max_results=1
)[0]
print(best_run.info)
# Out:
# <RunInfo: artifact_uri='s3://ipf-sds-datalake-dev-data-science-bucket/mlflow/2/57119b7eb46d4fbd9b5bafb37673bd98/artifacts', end_time=1730291527221, experiment_id='2', lifecycle_stage='active', run_id='57119b7eb46d4fbd9b5bafb37673bd98', run_name='input-example', run_uuid='57119b7eb46d4fbd9b5bafb37673bd98', start_time=1730291520534, status='FINISHED', user_id='sagemaker-user'>

# %% [markdown]
# # GET MSE FOR ALL RUNS

# %%
runs_with_mse = [r for r in runs if "mse" in r.data.metrics.keys()]
[r.data.metrics["mse"] for r in runs_with_mse]

# %% [markdown]
# # LOAD LIBRARIES

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # SETTINGS

# %%
mlflow_arn = "arn:aws:sagemaker:eu-west-1:575618486322:mlflow-tracking-server/dev-mlflow"

# %% [markdown]
# # SET THE ARN

# %%
mlflow.set_tracking_uri(mlflow_arn)

# %% [markdown]
# # INITIATE AUTOLOG

# %%
mlflow.autolog()
# Out:
# 2024/10/30 10:38:25 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %% [markdown]
# # BUILD A MODEL

# %%
db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
# MLflow triggers logging automatically upon model fitting
rf.fit(X_train, y_train)
# Out:
# 2024/10/30 10:38:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f9ea725dc59f4b1788375fab5e3ec202', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/10/30 10:38:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run bouncy-flea-417 at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/0/runs/f9ea725dc59f4b1788375fab5e3ec202.
# 2024/10/30 10:38:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/0.
# RandomForestRegressor(max_depth=6, max_features=3)

# %% [markdown]
# We didn't specify the experiment, therefore the run has been saved in Default experiment
# ![image.png](attachment:dcb1e952-1dec-46a4-a690-8c649e371c23.png)

# %% [markdown]
# # SPECIFY THE EXPERIMENT

# %%
mlflow.set_experiment("my-sample-experiment")
# Out:
# <Experiment: artifact_location='s3://ipf-sds-datalake-dev-data-science-bucket/mlflow/1', creation_time=1730284792305, experiment_id='1', last_update_time=1730284792305, lifecycle_stage='active', name='my-sample-experiment', tags={}>

# %% [markdown]
# # BUILD SOME MODELS

# %%
db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

rf = RandomForestRegressor(n_estimators=100, max_depth=4, max_features=3)
# MLflow triggers logging automatically upon model fitting
rf.fit(X_train, y_train)
# Out:
# 2024/10/30 10:41:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '10f02019d4ef4887a59616cbe73c30cd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/10/30 10:41:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run powerful-shrike-862 at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/1/runs/10f02019d4ef4887a59616cbe73c30cd.
# 2024/10/30 10:41:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/1.
# RandomForestRegressor(max_depth=4, max_features=3)

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=2, max_features=3)
rf.fit(X_train, y_train)
# Out:
# 2024/10/30 10:44:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a09897d69bc044d59240084a828d19fa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/10/30 10:44:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run worried-mole-263 at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/1/runs/a09897d69bc044d59240084a828d19fa.
# 2024/10/30 10:44:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://eu-west-1.experiments.sagemaker.aws/#/experiments/1.
# RandomForestRegressor(max_depth=2, max_features=3)

# %% [markdown]
# The run has been save in experiment "my-sample-experiment"
# ![obraz.png](attachment:21bb2121-ee7e-46ca-b87c-5548189cb19e.png)

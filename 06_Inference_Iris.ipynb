# %%
import boto3
import io
import numpy as np
import sagemaker
from sklearn.datasets import load_iris
from sagemaker import ModelPackage
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import CSVDeserializer
from sagemaker import get_execution_role
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Settings

# %%
model_package_group_name = 'Proj1' # model package group name. The latest model from this group will be used
output_path = "s3://sagemaker-bucket-ds/OUTPUT/IRIS/" # Path to output data
input_path = "s3://sagemaker-bucket-ds/INPUT/IRIS/" # Path to the file with inpt data
bucket_name = "sagemaker-bucket-ds"
input_file_name = "INPUT/IRIS/iris.csv"
input_path = f"s3://{bucket_name}/{input_file_name}"

# %% [markdown]
# ### Create clients

# %%
sagemaker_client = boto3.client('sagemaker')
s3_client = boto3.client('s3')
role = get_execution_role()
sagemaker_session = sagemaker.Session()

# %% [markdown]
# ### Create input data
# In normal case this data would be already available

# %%
iris = load_iris()
X = iris.data

# Convert the NumPy array to a CSV string
csv_buffer = io.StringIO()
np.savetxt(csv_buffer, X, delimiter=',', fmt='%.6f')
s3_client.put_object(Bucket=bucket_name, Key=input_file_name, Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'P85RW1ZV7PP79W1B',
#   'HostId': 'Q2ORiaHitBofv2kRRiBjoJGoDRd1dH41M4va99t6aEv0Nwo7eTvaPYi/HN9JDVrZyHtiL+sVKY8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Q2ORiaHitBofv2kRRiBjoJGoDRd1dH41M4va99t6aEv0Nwo7eTvaPYi/HN9JDVrZyHtiL+sVKY8=',
#    'x-amz-request-id': 'P85RW1ZV7PP79W1B',
#    'date': 'Wed, 19 Jun 2024 15:41:38 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"0cb2e05024525139c7065e36ffcefcf1"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"0cb2e05024525139c7065e36ffcefcf1"',
#  'ServerSideEncryption': 'AES256'}

# %% [markdown]
# ### Get ARN of model package

# %%
# List the model packages in the specified model package group
list_model_packages_response = sagemaker_client.list_model_packages(
    ModelPackageGroupName=model_package_group_name
)

# Print the list of model packages
model_packages = list_model_packages_response['ModelPackageSummaryList']
for model_package in model_packages:
    print("Model Package ARN: ", model_package['ModelPackageArn'])

# Get the ARN of the latest model package (if there are multiple)
model_package_arn = model_packages[0]['ModelPackageArn']  # Adjust as necessary
print("Latest Model Package ARN: ", model_package_arn)
# Out:
# Model Package ARN:  arn:aws:sagemaker:eu-west-1:211125740051:model-package/Proj1/1
# Latest Model Package ARN:  arn:aws:sagemaker:eu-west-1:211125740051:model-package/Proj1/1

# %% [markdown]
# ### Retrieve the model

# %%
# Create the model from the model package
model = ModelPackage(
    role=role,
    model_package_arn=model_package_arn,
    sagemaker_session=sagemaker_session
)

# %% [markdown]
# ### Create transformer

# %%
transformer = model.transformer(
    instance_count=1, 
    instance_type='ml.m5.large',
    assemble_with='Line',
    output_path=output_path)
# Out:
# INFO:sagemaker:Creating model with name: Proj1-2024-06-19-15-42-37-860

# %%
transformer.transform(data=input_path,
                      split_type='Line',
                       content_type='text/csv',
                       wait=True)
# Out:
# INFO:sagemaker:Creating transform job with name: Proj1-2024-06-19-15-42-45-073
# ................................2024-06-19 15:48:04,783 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:04,786 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:04,787 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2024-06-19 15:48:04 +0000] [13] [INFO] Starting gunicorn 20.0.4
# [2024-06-19 15:48:04 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2024-06-19 15:48:04 +0000] [13] [INFO] Using worker: gevent
# [2024-06-19 15:48:04 +0000] [17] [INFO] Booting worker with pid: 17
# [2024-06-19 15:48:05 +0000] [18] [INFO] Booting worker with pid: 18
# 2024-06-19 15:48:12,187 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,187 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,304 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,305 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,419 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,420 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,533 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,534 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 2024-06-19 15:48:12,647 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,648 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,758 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,759 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,869 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,870 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:12,981 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:12,981 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:12 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:12 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,091 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,092 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,202 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,203 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,315 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,315 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,431 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,431 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,545 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,546 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,662 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,662 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,773 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,774 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,884 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,885 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:13,996 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:13,996 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:13 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:13 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,106 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,107 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,217 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,217 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 2024-06-19 15:48:14,334 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,334 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 2024-06-19 15:48:14,445 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,446 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,556 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,557 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,668 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,668 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,779 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,779 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,889 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,889 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:14 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:14 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:14,999 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:14,999 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,110 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,111 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,221 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,222 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,334 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,334 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,445 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,446 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,557 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,557 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,668 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,669 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:15 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:15 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:15,779 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:15,780 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# ...
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,384 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,384 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,495 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,495 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,606 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,606 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,716 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,717 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,839 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,840 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:25,950 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:25,950 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:25 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:25 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:26,061 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:26,061 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:26 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:26 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:26,173 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:26,173 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:26 +0000] [18] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:26 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# 2024-06-19 15:48:26,285 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2024-06-19 15:48:26,285 INFO - sagemaker_sklearn_container.serving - Encountered an unexpected error.
# [2024-06-19 15:48:26 +0000] [17] [ERROR] Error handling request /ping
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 55, in handle
#     self.handle_request(listener_name, req, client, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/ggevent.py", line 143, in handle_request
#     super().handle_request(listener_name, req, sock, addr)
#   File "/miniconda3/lib/python3.8/site-packages/gunicorn/workers/base_async.py", line 106, in handle_request
#     respiter = self.wsgi(environ, resp.start_response)
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 140, in main
#     user_module_transformer, execution_parameters_fn = import_module(serving_env.module_name,
#   File "/miniconda3/lib/python3.8/site-packages/sagemaker_sklearn_container/serving.py", line 118, in import_module
#     user_module = importlib.import_module(module_name)
#   File "/miniconda3/lib/python3.8/importlib/__init__.py", line 118, in import_module
#     if name.startswith('.'):
# AttributeError: 'NoneType' object has no attribute 'startswith'
# 169.254.255.130 - - [19/Jun/2024:15:48:26 +0000] "GET /ping HTTP/1.1" 500 141 "-" "Go-http-client/1.1"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 transformer.transform(data=input_path,
#       2                       split_type='Line',
#       3                        content_type='text/csv',
#       4                        wait=True)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/transformer.py:318, in Transformer.transform(self, data, data_type, content_type, compression_type, split_type, job_name, input_filter, output_filter, join_source, experiment_config, model_client_config, batch_data_capture_config, wait, logs)
#     302 self.latest_transform_job = _TransformJob.start_new(
#     303     self,
#     304     data,
#    (...)
#     314     batch_data_capture_config,
#     315 )
#     317 if wait:
# --> 318     self.latest_transform_job.wait(logs=logs)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/transformer.py:686, in _TransformJob.wait(self, logs)
#     684 def wait(self, logs=True):
#     685     if logs:
# --> 686         self.sagemaker_session.logs_for_transform_job(self.job_name, wait=True)
#     687     else:
#     688         self.sagemaker_session.wait_for_transform_job(self.job_name)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/session.py:5937, in Session.logs_for_transform_job(self, job_name, wait, poll)
#    5934 if state == LogState.COMPLETE:
#    5935     break
# -> 5937 time.sleep(poll)
#    5939 if state == LogState.JOB_COMPLETE:
#    5940     state = LogState.COMPLETE
#
# KeyboardInterrupt:

# %%
# The ModelName should be derived from the model package ARN or set manually
model_name = model_package_arn.split('/')[-1]
model.name = model_name

# %% [markdown]
# ### Create an endpoint configuration

# %%
endpoint_config_name = 'Iris-endpoint-config'
endpoint_config_response = sagemaker_client.create_endpoint_config(
    EndpointConfigName=endpoint_config_name,
    ProductionVariants=[
        {
            'VariantName': 'AllTraffic',
            'ModelName': model.name,
            'InstanceType': 'ml.m5.large',
            'InitialInstanceCount': 1
        }
    ]
)
print("Endpoint Config Arn: ", endpoint_config_response['EndpointConfigArn'])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 endpoint_config_name = 'Iris-endpoint-config'
# ----> 2 endpoint_config_response = sagemaker_client.create_endpoint_config(
#       3     EndpointConfigName=endpoint_config_name,
#       4     ProductionVariants=[
#       5         {
#       6             'VariantName': 'AllTraffic',
#       7             'ModelName': model.name,
#       8             'InstanceType': 'ml.m5.large',
#       9             'InitialInstanceCount': 1
#      10         }
#      11     ]
#      12 )
#      13 print("Endpoint Config Arn: ", endpoint_config_response['EndpointConfigArn'])
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:553, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     549     raise TypeError(
#     550         f"{py_operation_name}() only accepts keyword arguments."
#     551     )
#     552 # The "self" in this scope is referring to the BaseClient.
# --> 553 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:1009, in BaseClient._make_api_call(self, operation_name, api_params)
#    1005     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1006         "Code"
#    1007     )
#    1008     error_class = self.exceptions.from_code(error_code)
# -> 1009     raise error_class(parsed_response, operation_name)
#    1010 else:
#    1011     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateEndpointConfig operation: Could not find model "1".

# %%
# Create an endpoint
endpoint_name = 'model-endpoint'
endpoint_response = sagemaker_client.create_endpoint(
    EndpointName=endpoint_name,
    EndpointConfigName=endpoint_config_name
)
print("Endpoint Arn: ", endpoint_response['EndpointArn'])

# Wait for the endpoint to be in service
sagemaker_client.get_waiter('endpoint_in_service').wait(EndpointName=endpoint_name)
print(f"Endpoint {endpoint_name} is in service!")

# Perform inference
predictor = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=CSVSerializer(),
    deserializer=CSVDeserializer()
)

# Example data for inference (in CSV format)
input_data = "1.0, 2.0, 3.0, 4.0"  # Replace with actual data

# Perform the prediction
prediction = predictor.predict(input_data)
print("Prediction: ", prediction)
